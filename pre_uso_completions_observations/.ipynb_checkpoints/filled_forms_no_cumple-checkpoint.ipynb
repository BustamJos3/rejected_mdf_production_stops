# %%
import pandas as pd #modules
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import os
import pathlib
from pathlib import Path
from datetime import datetime, timedelta
import itertools
import string

# %% [markdown]
# # Load shift hours

# %%
def find_files_by_format(root_folder, file_format):
    """
    Searches for all files with a specific format in a folder and its subfolders.

    Parameters:
    root_folder (str): The root folder to start the search.
    file_format (str): The file extension to search for (e.g., '.pptx', '.txt').

    Returns:
    list: A list of absolute paths to all matching files.
    """
    matching_files = []

    # Traverse directories recursively
    for root, dirs, files in os.walk(root_folder):
        for file in files:
            # Check if the file has the specified format
            if file.lower().endswith(file_format.lower()):  # Case-insensitive check
                # Append the full path of the file
                matching_files.append(os.path.join(root, file))

    return matching_files

# %%
def operate_mercyful_times(hour,operand): #function to apply modifications on shift hours
    from datetime import datetime, timedelta
    delta_time_mercy=timedelta(minutes=0)
    mercy_flag=False #bool to activate mercy mode
    if mercy_flag:
        delta_time_mercy=timedelta(minutes=10) #time delta to substract and add to initial and final hours
    if operand=="+" and mercy_flag: #to add to final hour
        result_hour=eval("datetime.strptime(hour, '%H:%M:%S'){}delta_time_mercy".format(operand))
        result_hour=result_hour.time()
        return result_hour
    elif operand=="-" and mercy_flag: #to substract to initial hour
        result_hour=eval("datetime.strptime(hour, '%H:%M:%S'){}delta_time_mercy".format(operand))
        result_hour=result_hour.time()
        return result_hour
    else:
        return eval("datetime.strptime(hour, '%H:%M:%S').time()")

# %%
str___splitter=lambda x: x.split("_")

# %% [markdown]
# # Function to find cloud (OneDrive) folder

# %%
import os

def find_reports_in_onedrive():
    """
    Scans the subfolders under the current user's OneDrive folder (including variations like 'OneDrive - Company Name')
    and returns the paths of all folders with the prefix 'reports'.

    Returns:
        list: A list of full paths to folders starting with 'reports', or an empty list if none are found.
    """
    # Get the base path to the user's home directory
    user_home = os.path.expanduser("~")

    # Find the OneDrive folder (handles variations like "OneDrive - Company Name")
    onedrive_folder = None
    for folder in os.listdir(user_home):
        if folder.startswith("OneDrive -"):
            onedrive_folder = os.path.join(user_home, folder)
            break

    if not onedrive_folder:
        raise FileNotFoundError("OneDrive folder not found for the current user.")

    # Search for folders with the prefix 'reports' in the OneDrive directory
    report_folders = []
    for root, dirs, files in os.walk(onedrive_folder):
        for dir_name in dirs:
            if dir_name.lower().startswith("reports"):
                report_folders.append(os.path.join(root, dir_name))

    return report_folders

# %%
reports_paths=find_reports_in_onedrive()
reports_paths
# Out:
# ['C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_control_variables_refinacion',
#  'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_cuchillas',
#  'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_eventos',
#  'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_humidity_measures',
#  'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_ops_pendings',
#  'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_pre-usos_diligenciamiento_no_cumple',
#  'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_quality_deviations',
#  'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_refination_deviations',
#  'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_visualizacion_data_produccion',
#  'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\control_room\\reports_causa_rechazos']

# %%
str_folder_searcher="reports_pre-usos_diligenciamiento_no_cumple"
for report_path in reports_paths:
    if str_folder_searcher in report_path:
        path=Path(reports_paths[reports_paths.index(report_path)])
path=Path.joinpath(path,r"source_and_return_data")
path
# Out:
# WindowsPath('C:/Users/jdbustamante/OneDrive - Duratex SA/reports_pre-usos_diligenciamiento_no_cumple/source_and_return_data')

# %%
os.chdir(path) #change working directory to respective reports folder
os.getcwd()
# Out:
# 'C:\\Users\\jdbustamante\\OneDrive - Duratex SA\\reports_pre-usos_diligenciamiento_no_cumple\\source_and_return_data'

# %%
shifts_hours=pd.read_csv(r".\shifts_hours.txt",delimiter=",")
shifts_hours_cols=list(shifts_hours.columns)
shifts_hours.loc[:,shifts_hours_cols[0]]=shifts_hours.loc[:,shifts_hours_cols[0]].apply(lambda x: operate_mercyful_times(hour=x,operand="-"))
shifts_hours.loc[:,shifts_hours_cols[1]]=shifts_hours.loc[:,shifts_hours_cols[1]].apply(lambda x: operate_mercyful_times(hour=x,operand="+"))
shifts_hours.loc[:,shifts_hours_cols[-1]]=shifts_hours.loc[:,shifts_hours_cols[-1]].apply(str___splitter)
shifts_hours
# Out:
#   initial_hour finalitation_hour  shift  \
# 0     22:00:00          06:00:00      1
# 1     06:00:00          14:00:00      2
# 2     14:00:00          22:00:00      3
# 3     07:00:00          16:30:00      4
#
#                                              systems
# 0  [refinación, planta térmica, formación y prens...
# 1  [refinación, planta térmica, formación y prens...
# 2  [refinación, planta térmica, formación y prens...
# 3                           [mantenimiento mecánico]

# %% [markdown]
# # Generation of querie to filter dates to look up completion dates

# %%
def get_monday_of_week():
    """
    This function, `get_monday_of_week`, returns the date  
    of the Monday in the current week based on today's date.  
    
    It first retrieves today's date using `datetime.today()`  
    and then determines the current weekday using  
    `today.weekday()`, where Monday is represented by 0.  
    
    Next, it calculates the number of days to subtract to  
    reach Monday by taking the value of `today.weekday()`  
    and subtracting that number of days using `timedelta`.  
    
    Finally, it formats the result as 'YYYY-MM-DD' and  
    returns it as the output.  
    """
    # Obtener la fecha de hoy
    today = datetime.today()
    # Calcular la diferencia de días hasta el lunes (Monday = 0)
    delta = today.weekday()  # weekday() devuelve 0 para lunes
    # Restar los días necesarios para llegar al lunes
    monday = today - timedelta(days=delta)
    # Retornar la fecha en formato YYYY-MM-DD
    return monday.date()

# %%
def date_limits(moment_of_week=True,day_separation=1):
    """change dates limits to filter completions 
    base on bool (default True), whether is weekend 
    or in between the week and if the moment in between 
    the week is 1 day apart or more"""
    if not moment_of_week: #day of querie is not in between the week
        day_separation=3 #querie to consult sunday (1), saturday (2) and friday (3)
        get_current_recent_date=get_monday_of_week() #get the date of monday from current week
    else:
        get_current_recent_date=datetime.now()
        print(get_current_recent_date)
    day_to_stop_search=get_current_recent_date-timedelta(days=1) #check from yesterday
    print(day_to_stop_search)
    day_before_yesterday=day_to_stop_search - timedelta(days=day_separation) #get yesterday date to check fraction of T1 and T2 y T3
    print(day_before_yesterday)
    return day_to_stop_search,day_before_yesterday

# %% [markdown]
# ## Construct separation of days from last execution date to day to search in pre-usos
# * store last execution date to compute separation of days

# %%
today=datetime.now() #get date_time from today
today_date=today.date() #get date
# Specify the file name
file_name = r".\date_time_last_exec.txt"
if today_date==get_monday_of_week(): #if it is monday
    not_weekend=False #moment of querie is weekend
    separation_of_days=None
else:
    not_weekend=True #moment of querie is not weekend
    # Read the content of the file and parse it as a datetime object
    with open(file_name, 'r') as file:
        last_execution = datetime.strptime(file.read().strip(), '%Y-%m-%d %H:%M:%S') #load last execution
        last_execution_date=last_execution.date()
        print(last_execution_date)
    separation_of_days=today_date-last_execution_date
    separation_of_days=separation_of_days.days if separation_of_days.days>0 else 365+separation_of_days.days #days separation to make queries in between week of more than 1 day
    print("separation",separation_of_days)
"""export last execution date into txt"""
# Write the date_time variable into the file
list_current_reports=find_files_by_format(Path.joinpath(path,"pptx_reports"),".pptx")
yesterday=today_date-timedelta(days=1)
most_recent_report_title_yesterday=True #flag to check yesterday report existance
for report_title in list_current_reports:
    if yesterday.strftime('%Y-%m-%d') in report_title:
        most_recent_report_title_not_yesterday=False
if most_recent_report_title_not_yesterday: #if a report with yesterday date is not already generated, update last execution
    with open(file_name, 'w') as file:
        print("no matches in reports, proceed to update last execution")
        file.write(today.strftime('%Y-%m-%d %H:%M:%S'))
day_to_stop_search_querie,day_before_yesterday_querie=date_limits(moment_of_week=not_weekend,day_separation=separation_of_days)
day_before_yesterday_querie=datetime.combine(day_before_yesterday_querie,shifts_hours.at[0,"initial_hour"])
day_to_stop_search_querie=datetime.combine(day_to_stop_search_querie,shifts_hours.at[2,"finalitation_hour"])
day_to_stop_search_querie,day_before_yesterday_querie
# Out:
# 2025-01-19
# 2025-01-16
# (datetime.datetime(2025, 1, 19, 22, 0), datetime.datetime(2025, 1, 16, 22, 0))

# %% [markdown]
# # Load pre-usos files

# %%
directory = Path(r".\pre_usos_actual") #get current work directory
matching_files = list(directory.glob("*Pre-Uso*.xlsx"))  # Busca archivos que tengan extensión .xlsx
print("Archivos encontrados:", matching_files)
# Out:
# Archivos encontrados: [WindowsPath('pre_usos_actual/Pre-Uso Astillado.xlsx'), WindowsPath('pre_usos_actual/Pre-Uso BP2.xlsx'), WindowsPath('pre_usos_actual/Pre-Uso Formación y Prensa.xlsx'), WindowsPath('pre_usos_actual/Pre-Uso Lijadora.xlsx'), WindowsPath('pre_usos_actual/Pre-Uso Mantenimiento Mecánico.xlsx'), WindowsPath('pre_usos_actual/Pre-Uso Moduladora y Carpintería.xlsx'), WindowsPath('pre_usos_actual/Pre-Uso Planta Térmica.xlsx'), WindowsPath('pre_usos_actual/Pre-Uso Refinación.xlsx'), WindowsPath('pre_usos_actual/Pre-Uso Schelling.xlsx')]

# %%
dict_data_pointer={} #dict to store files as dfs
for i in matching_files: # Read the Excel file 
    file_path = str(i)  # Update this with the path
    try:
        df = pd.read_excel(file_path,sheet_name="Form1") #specific sheet call for english origin forms
    except:
        df = pd.read_excel(file_path)
    print(file_path)
    df_name=file_path.split(str(directory)+"\\")[-1].split(".")[0] #split str with "." char and take the file name
    dict_data_pointer[f"{df_name}"]=df #store filtered df in dictionary data pointer
print(list(dict_data_pointer.keys())) #see keys on dictionary to check callability
# Out:
# pre_usos_actual\Pre-Uso Astillado.xlsx
# pre_usos_actual\Pre-Uso BP2.xlsx
# pre_usos_actual\Pre-Uso Formación y Prensa.xlsx
# pre_usos_actual\Pre-Uso Lijadora.xlsx
# pre_usos_actual\Pre-Uso Mantenimiento Mecánico.xlsx
# pre_usos_actual\Pre-Uso Moduladora y Carpintería.xlsx
# pre_usos_actual\Pre-Uso Planta Térmica.xlsx
# pre_usos_actual\Pre-Uso Refinación.xlsx
# pre_usos_actual\Pre-Uso Schelling.xlsx
# ['Pre-Uso Astillado', 'Pre-Uso BP2', 'Pre-Uso Formación y Prensa', 'Pre-Uso Lijadora', 'Pre-Uso Mantenimiento Mecánico', 'Pre-Uso Moduladora y Carpintería', 'Pre-Uso Planta Térmica', 'Pre-Uso Refinación', 'Pre-Uso Schelling']

# %% [markdown]
# # Get forms done respect the shifts

# %% [markdown]
# # Make df to create excel with table of completions and specific rules of laboral days

# %%
day_difference=day_to_stop_search_querie-day_before_yesterday_querie
day_difference=day_difference.days
day_difference
# Out:
# 3

# %% [markdown]
# ## change creation of row_report with the reading from loading the actual workbook with the dates

# %%
df_pre_uso_completion_report=pd.read_excel(Path.joinpath(path,r"pre_uso_produccion_report_copia\Preusos Producción.xlsx"))
df_pre_uso_completion_report_cols=list(df_pre_uso_completion_report.columns)
array_data=[["","",""]*day_difference]*len(df_pre_uso_completion_report_cols[2:])
array_data=list(map(list, zip(*array_data))) #transpose list to match df input data format
print(array_data)
shifts=3
dates_of_interest= [ [date]*shifts for date in [day_to_stop_search_querie.date() - timedelta(days=x) for x in range(day_difference)] ]
dates_of_interest=list(itertools.chain.from_iterable(dates_of_interest))
if len(dates_of_interest)>1:
    dates_of_interest=sorted(dates_of_interest)
multi_index=[ dates_of_interest,["1","2","3"]*day_difference ]
print(multi_index)
df_check_completion=pd.DataFrame(data=array_data,index=multi_index,columns=df_pre_uso_completion_report_cols[2:])
df_check_completion.index.names =['Día',df_pre_uso_completion_report_cols[1]]
df_check_completion
# Out:
# [['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '']]
# [[datetime.date(2025, 1, 17), datetime.date(2025, 1, 17), datetime.date(2025, 1, 17), datetime.date(2025, 1, 18), datetime.date(2025, 1, 18), datetime.date(2025, 1, 18), datetime.date(2025, 1, 19), datetime.date(2025, 1, 19), datetime.date(2025, 1, 19)], ['1', '2', '3', '1', '2', '3', '1', '2', '3']]
#                  Lijadora Schelling Moduladora y Carpintería BP2 Astillado  \
# Día        Turno
# 2025-01-17 1
#            2
#            3
# 2025-01-18 1
#            2
#            3
# 2025-01-19 1
#            2
#            3
#
#                  Mantenimiento Mecánico Formación y Prensa Refinación  \
# Día        Turno
# 2025-01-17 1
#            2
#            3
# 2025-01-18 1
#            2
#            3
# 2025-01-19 1
#            2
#            3
#
#                  Planta Térmica
# Día        Turno
# 2025-01-17 1
#            2
#            3
# 2025-01-18 1
#            2
#            3
# 2025-01-19 1
#            2
#            3

# %% [markdown]
# ## Function to check shifts

# %%
def shift_checker(date_time=None,system_to_test=None):
    system=system_to_test.lower() #convert system name to lowercase
    print(date_time)
    time_of_interest=date_time.time() #take the hh:mm:ss of entry in completion date_time
    initial_shift_hours=shifts_hours.loc[:,[shifts_hours_cols[0]]].values
    final_shift_hours=shifts_hours.loc[:,[shifts_hours_cols[1]]].values
    available_systems=[sys[0] for sys in shifts_hours.loc[:,[shifts_hours_cols[-1]]].values]
    for available_system in available_systems: #check which is the shift of the system
        if system in available_system:
            print(available_system)
            matching_shift=available_systems.index(available_system)+1
            print(matching_shift)
            if matching_shift<4: #system is from shift 1,2 or 3
                print(system," in ",matching_shift)
                if time_of_interest>=initial_shift_hours[0][0] or time_of_interest<final_shift_hours[0][0]: #check if it is shift 1
                    shift_result="T1"
                if time_of_interest>=initial_shift_hours[1][0] and time_of_interest<final_shift_hours[1][0]: #check if it is shift 2
                    shift_result="T2"
                if time_of_interest>=initial_shift_hours[2][0] and time_of_interest<final_shift_hours[2][0]: #check if it is shift 3
                    shift_result="T3"
            else: #system if from shift 4
                if time_of_interest>=initial_shift_hours[3][0] and time_of_interest<final_shift_hours[3][0]: #check if it is shift 3
                    shift_result="T4"
            return shift_result
        else:
            print("sistema no reconocido en {}".format(available_system))

# %% [markdown]
# ## Apply check of shifts on dfs pre-usos

# %%
dict_result_shift_checker={}
for pre_uso in dict_data_pointer.keys(): #run throug all dfs of pre-usos
    df=dict_data_pointer[pre_uso] #select respective df
    df_columns=list(df.columns)
    df.loc[:,df_columns[1]] = pd.to_datetime(df.loc[:,df_columns[1]], format='%Y-%m-%d %H:%M:%S') # Convierte las columnas al formato datetime
    df_shift_dates=df.loc[( df[df_columns[1]]>=day_before_yesterday_querie )&( df[df_columns[1]]<=day_to_stop_search_querie )] #filter df to get completions of desired date
    df_shift_dates=df_shift_dates.sort_values(by=df_columns[1],ascending=False)
    df_shift_dates=df_shift_dates.fillna(value=" ")
    df_np_times=df_shift_dates.loc[:,df_columns[1]].values #get the dates of current df filtered
    """start shift check"""
    system_to_check_in=pre_uso.lower().split("pre-uso ")[-1]
    print(f"sistema a chequear: {system_to_check_in}")
    dict_result_shift_checker[system_to_check_in]=[]
    for date_np_time in df_np_times:
        date_timestamp=pd.Timestamp(date_np_time)
        print(f"fecha de diligenciamiento: {date_timestamp}")
        shift_checked=shift_checker(date_time=date_timestamp,system_to_test=system_to_check_in) #store shift
        print(f"turno asignado: {shift_checked}")
        dict_result_shift_checker[system_to_check_in].append((date_timestamp,shift_checked))
    dict_result_shift_checker[system_to_check_in]=sorted(dict_result_shift_checker[system_to_check_in])
dict_result_shift_checker
# Out:
# sistema a chequear: astillado
# fecha de diligenciamiento: 2025-01-19 20:10:43
# 2025-01-19 20:10:43
# ['refinación', 'planta térmica', 'formación y prensa', 'bp2', 'astillado', 'mantenimiento mecánico']
# 1
#   (Timestamp('2025-01-19 06:19:00'), 'T2'),
#   (Timestamp('2025-01-19 14:03:32'), 'T3')],
#  'schelling': [(Timestamp('2025-01-17 07:37:40'), 'T2'),
#   (Timestamp('2025-01-17 18:43:34'), 'T3'),
#   (Timestamp('2025-01-18 07:09:54'), 'T2'),
#   (Timestamp('2025-01-18 15:47:22'), 'T3')]}

# %% [markdown]
# ## asign values on df of completion

# %%
df_check_completion_cols=df_check_completion.columns
for (key_shift_checker,values_shift_checker) in dict_result_shift_checker.items():
    print(key_shift_checker,values_shift_checker)
    for current_col_check_completion in df_check_completion_cols:
        if key_shift_checker in current_col_check_completion.lower():
            print(f"sistema {key_shift_checker} in {current_col_check_completion}")
            for date_time,shift in values_shift_checker: #begin asignation by dates and shifts
                current_date_of_shift_checker=date_time.date()
                idx_shift=shift[-1]
                print(current_date_of_shift_checker)
                if current_date_of_shift_checker not in dates_of_interest:
                    current_date_of_shift_checker=min(dates_of_interest) #if date not in dates_of_interest, take the youngest date
                print(idx_shift)
                df_check_completion.loc[(current_date_of_shift_checker, idx_shift), current_col_check_completion]="OK" #asignation
df_check_completion
# Out:
# astillado [(Timestamp('2025-01-17 02:31:33'), 'T1'), (Timestamp('2025-01-17 13:42:57'), 'T2'), (Timestamp('2025-01-17 19:10:31'), 'T3'), (Timestamp('2025-01-18 04:56:00'), 'T1'), (Timestamp('2025-01-18 13:16:27'), 'T2'), (Timestamp('2025-01-18 14:24:43'), 'T3'), (Timestamp('2025-01-19 05:05:31'), 'T1'), (Timestamp('2025-01-19 12:53:14'), 'T2'), (Timestamp('2025-01-19 20:10:43'), 'T3')]
# sistema astillado in Astillado
# 2025-01-17
# 1
# 2025-01-17
# 2
# 2025-01-17
# 3
# 2025-01-18
# 1
# 2025-01-18
# 2
# 2025-01-18
# 3
# 2025-01-19
# 1
# 2025-01-19
# 2
# 2025-01-19
# 3
# bp2 []
# sistema bp2 in BP2
# formación y prensa [(Timestamp('2025-01-16 22:37:57'), 'T1'), (Timestamp('2025-01-17 01:51:32'), 'T1'), (Timestamp('2025-01-17 06:22:05'), 'T2'), (Timestamp('2025-01-17 06:24:09'), 'T2'), (Timestamp('2025-01-17 14:12:29'), 'T3'), (Timestamp('2025-01-17 14:26:05'), 'T3'), (Timestamp('2025-01-17 22:03:49'), 'T1'), (Timestamp('2025-01-18 06:12:31'), 'T2'), (Timestamp('2025-01-18 06:13:22'), 'T2'), (Timestamp('2025-01-18 15:07:33'), 'T3'), (Timestamp('2025-01-18 19:25:26'), 'T3'), (Timestamp('2025-01-18 22:22:21'), 'T1'), (Timestamp('2025-01-19 06:01:11'), 'T2'), (Timestamp('2025-01-19 06:13:06'), 'T2'), (Timestamp('2025-01-19 06:19:17'), 'T2'), (Timestamp('2025-01-19 14:02:02'), 'T3'), (Timestamp('2025-01-19 14:12:11'), 'T3')]
# sistema formación y prensa in Formación y Prensa
# 2025-01-16
# 1
# 2025-01-17
# 1
# 2025-01-17
# 2
# 2025-01-17
# 2
# refinación [(Timestamp('2025-01-16 22:37:20'), 'T1'), (Timestamp('2025-01-17 01:52:44'), 'T1'), (Timestamp('2025-01-17 06:23:02'), 'T2'), (Timestamp('2025-01-17 06:28:55'), 'T2'), (Timestamp('2025-01-17 14:13:03'), 'T3'), (Timestamp('2025-01-17 14:27:00'), 'T3'), (Timestamp('2025-01-17 15:02:32'), 'T3'), (Timestamp('2025-01-17 22:03:25'), 'T1'), (Timestamp('2025-01-18 06:09:36'), 'T2'), (Timestamp('2025-01-18 15:08:25'), 'T3'), (Timestamp('2025-01-18 17:04:38'), 'T3'), (Timestamp('2025-01-18 22:23:29'), 'T1'), (Timestamp('2025-01-19 06:12:45'), 'T2'), (Timestamp('2025-01-19 06:19:00'), 'T2'), (Timestamp('2025-01-19 14:03:32'), 'T3')]
# sistema refinación in Refinación
# 2025-01-16
# 1
# 2025-01-17
# 1
# 2025-01-17
# 2
# 2025-01-17
# 2
# 2025-01-17
# 3
# 2025-01-17
# 3
# 2025-01-17
# 3
# 2025-01-17
# 1
# 2025-01-18
# 2
# 2025-01-18
# 3
# 2025-01-18
# 3
# 2025-01-18
# 1
# 2025-01-19
# 2
# 2025-01-19
# 2
# 2025-01-19
# 3
# schelling [(Timestamp('2025-01-17 07:37:40'), 'T2'), (Timestamp('2025-01-17 18:43:34'), 'T3'), (Timestamp('2025-01-18 07:09:54'), 'T2'), (Timestamp('2025-01-18 15:47:22'), 'T3')]
# sistema schelling in Schelling
# 2025-01-17
# 2
# 2025-01-17
# 3
# 2025-01-18
# 2
# 2025-01-18
# 3
#                  Lijadora Schelling Moduladora y Carpintería BP2 Astillado  \
# Día        Turno
# 2025-01-17 1                                                            OK
#            2           OK        OK                                     OK
#            3           OK        OK                       OK            OK
# 2025-01-18 1                                                            OK
#            2           OK        OK                       OK            OK
#            3                     OK                                     OK
# 2025-01-19 1                                                            OK
#            2           OK                                 OK            OK
#            3                                                            OK
#
#                  Mantenimiento Mecánico Formación y Prensa Refinación  \
# Día        Turno
# 2025-01-17 1                         OK                 OK         OK
#            2                         OK                 OK         OK
#            3                                            OK         OK
# 2025-01-18 1                         OK                 OK         OK
#            2                                            OK         OK
#            3                                            OK         OK
# 2025-01-19 1
#            2                                            OK         OK
#            3                                            OK         OK
#
#                  Planta Térmica
# Día        Turno
# 2025-01-17 1                 OK
#            2                 OK
#            3                 OK
# 2025-01-18 1                 OK
#            2                 OK
#            3                 OK
# 2025-01-19 1
#            2                 OK
#            3                 OK

# %% [markdown]
# ## export completion df to excel

# %%
path_to_export=Path.joinpath(path,rf'row_date_report\{day_to_stop_search_querie.date()}.xlsx')
print(path_to_export)
df_check_completion.to_excel(path_to_export)
# Out:
# C:\Users\jdbustamante\OneDrive - Duratex SA\reports_pre-usos_diligenciamiento_no_cumple\source_and_return_data\row_date_report\2025-01-19.xlsx

# %% [markdown]
# # Filter dfs of preusos on one cell to get "No Cumple"

# %%
dict_data_no_cumple={}
for pre_uso_key in list(dict_data_pointer.keys()):
    print(pre_uso_key)
    """select df"""
    df=dict_data_pointer[pre_uso_key]
    """save columns names"""
    df_columns=list(df.columns)
    # Convierte las columnas al formato datetime
    df.loc[:,df_columns[1]] = pd.to_datetime(df.loc[:,df_columns[1]], format='%Y-%m-%d %H:%M:%S')
    """filter dates to check completion"""
    df_shift_dates=df.loc[( df[df_columns[1]]>=day_before_yesterday_querie )&( df[df_columns[1]]<=day_to_stop_search_querie )] #get completion dates
    df_shift_dates=df_shift_dates.sort_values(by=df_columns[1],ascending=False)
    df_shift_dates=df_shift_dates.fillna(value=" ")
    
    """create df to check observations on No Cumple entries"""
    df_to_concatenate=pd.DataFrame() #df to begin concatenation
    for col_name in df_columns[8:]:
        #print(col_name)
        print(df_shift_dates[col_name])
        #try: #try to get No completion entries
        df_col_name_querie=df_shift_dates.loc[ (df_shift_dates[col_name].astype("str").str.contains("No Cumple"))|(df_shift_dates[col_name].astype("str").str.contains("No cumple")) ] #--->reformat to make cleaner solution
        #except: #continue cause there is no entries with No Cumple
            #continue
        if len(df_col_name_querie)>0: #"No Cumple" is found in current col
            print(col_name)
            df_with_concatenate=df_col_name_querie.loc[:,[col_name]]#df_col_name_querie.loc[:,[df_columns[1],df_columns[-1],col_name]]
            df_to_concatenate=pd.concat([df_to_concatenate, df_with_concatenate],axis=1, sort=False)
    indexes_dates_observs=list(df_to_concatenate.index)
    df_to_concatenate=pd.concat([df_shift_dates.loc[indexes_dates_observs,[df_columns[-1],df_columns[1] ]],df_to_concatenate],axis=1, sort=False)
    df_to_concatenate=df_to_concatenate.fillna(value=" ")#sort_values(by=df_columns[1])
    if len(df_to_concatenate)>0: #only take the queries that are not empty
        dict_data_no_cumple[pre_uso_key]=df_to_concatenate
# Out:
# Pre-Uso Astillado
# 212    Cumple
# 211    Cumple
# 210    Cumple
# 209    Cumple
# 208    Cumple
# 207    Cumple
# 206    Cumple
# 205    Cumple
# 204    Cumple
# Name: ¿El aire acondicionado esta operativo?, dtype: object
# 212    No cumple
# 211    No cumple
# 210    No cumple
# 209    No cumple
# 208    No cumple
# 207    No cumple
# 206    No cumple
# 205    No cumple
# 204    No cumple
# Name: ¿Las cajas de control, empaques, cableado y tomas eléctricos se encuentran cerrados y en buen estado?, dtype: object
# ¿Las cajas de control, empaques, cableado y tomas eléctricos se encuentran cerrados y en buen estado?
# 212    No Cumple
# 211    No Cumple
# 210    No Cumple
# 209    No Cumple
# 208    No Cumple
# 207    No Cumple
# 206    No Cumple
# 205    No Cumple
# 204    No Cumple
# Name: ¿Están ubicadas y funcionales las 6 guardas de seguridad del tambor descortezador?, dtype: object
# ¿Están ubicadas y funcionales las 6 guardas de seguridad del tambor descortezador?
# 212    Cumple
# 211    Cumple
# 210    Cumple
# 209    Cumple
# 208    Cumple
# 207    Cumple
# 206    Cumple
# 205    Cumple
# 204    Cumple
# Name: ¿Los interruptores de paro de emergencia están funcionales?, dtype: object
# 212       Cumple
# 211       Cumple
# 210       Cumple
# 209    No Cumple
# 208       Cumple
# 207       Cumple
# 206       Cumple
# 205       Cumple
# 204       Cumple
# Name: ¿La unidad hidráulica y accesorios presentan algún tipo de fuga?, dtype: object
# ¿La unidad hidráulica y accesorios presentan algún tipo de fuga?
# 212    No cumple
# 211    No cumple
# 210    No cumple
# 209       Cumple
# 208    No cumple
# 207    No cumple
# 206    No cumple
# 205    No cumple
# 204    No cumple
# Name: ¿Las escaleras, pasamanos y paros de cuerdas están funcionales y libre de obstrucciones?, dtype: object
# ¿Las escaleras, pasamanos y paros de cuerdas están funcionales y libre de obstrucciones?
# 212    No cumple
# 211    No cumple
# 210    No cumple
# 209    No cumple
# 208    No cumple
# 207    No cumple
# 206    No cumple
# 205    No cumple
# 204    No cumple
# Name: ¿Las barreras perimetrales de la mesa transversal están ubicadas y funcionales?, dtype: object
# ¿Las barreras perimetrales de la mesa transversal están ubicadas y funcionales?
# 212
# 211
# 210
# 209
# 208
# 207
# 206
# 205
# 204
# Name: ¿Las guardas de seguridad de la mesa transversal están ubicadas y funcionales?, dtype: object
# 212    No cumple
# 211    No cumple
# 210    No cumple
# 209       Cumple
# 208    No cumple
# 207    No cumple
# 206    No cumple
# 205    No cumple
# 204    No cumple
# Name: ¿Están ubicadas y funcionales las guardas de seguridad de las bandas de descarga de corteza, transportadora de tronco y alimentación al chipper?, dtype: object
# ¿Están ubicadas y funcionales las guardas de seguridad de las bandas de descarga de corteza, transportadora de tronco y alimentación al chipper?
# 212    No cumple
# 211    No cumple
# 210    No cumple
# 209    No cumple
# 208    No cumple
# 207    No cumple
# 206    No cumple
# 205    No cumple
# 204    No cumple
# Name: ¿Las escaleras, pasamanos y senderos peatonales están libre de obstrucciones y en buen estado?, dtype: object
# ¿Las escaleras, pasamanos y senderos peatonales están libre de obstrucciones y en buen estado?
# 212    No cumple
# 211    No cumple
# 210    No cumple
# 209    No cumple
# 208    No cumple
# 207    No cumple
# 206    No cumple
# 205    No cumple
# 204    No cumple
# Name: ¿Las barreras perimetrales de las poleas de las poleas del Chipper están ubicadas y funcionales?, dtype: object
# ¿Las barreras perimetrales de las poleas de las poleas del Chipper están ubicadas y funcionales?
# 212    No cumple
# 211    No cumple
# 210    No cumple
# 209    No cumple
# 208    No cumple
# 207    No cumple
# 206    No cumple
# 205    No cumple
# 204    No cumple
# Name: ¿Las guardas de seguridad de los rodillos dentados están ubicadas y funcionales (8 unidades)?, dtype: object
# ¿Las guardas de seguridad de los rodillos dentados están ubicadas y funcionales (8 unidades)?
# 212    No cumple
# 211       Cumple
# 210       Cumple
# 209       Cumple
# 208       Cumple
# 207    No cumple
# 206       Cumple
# 205       Cumple
# 204       Cumple
# Name: ¿La unidad hidráulica del chipper cuenta con su guarda de seguridad?, dtype: object
# ¿La unidad hidráulica del chipper cuenta con su guarda de seguridad?
# 212    No cumple
# 211    No cumple
# 210    No cumple
# 209    No cumple
# 208    No cumple
# 207    No cumple
# 206    No cumple
# 205    No cumple
# 204    No cumple
# Name: ¿Las cajas eléctricas, el pin de bloqueo y los tornillos de ajustes del Chipper están ajustados?, dtype: object
# ¿Las cajas eléctricas, el pin de bloqueo y los tornillos de ajustes del Chipper están ajustados?
# 212       Cumple
# 211       Cumple
# 210       Cumple
# 209    No cumple
# 208       Cumple
# 207       Cumple
# 206       Cumple
# 205       Cumple
# 204       Cumple
# Name: ¿Se encuentran cerradas las tapas del shute?, dtype: object
# ¿Se encuentran cerradas las tapas del shute?
# 212       Cumple
# 211       Cumple
# 210    No cumple
# 209       Cumple
# 208       Cumple
# 207    No cumple
# 206       Cumple
# 205    No cumple
# 204       Cumple
# Name: ¿La guarda de seguridad de los tornillos gemelos están ubicadas y funcionales?, dtype: object
# ¿La guarda de seguridad de los tornillos gemelos están ubicadas y funcionales?
# 212       Cumple
# 211    No cumple
# 210    No cumple
# 209       Cumple
# 208    No cumple
# 207    No cumple
# 206       Cumple
# 205    No cumple
# 204       Cumple
# Name: ¿La guarda de seguridad y la plataforma de la banda 114 están en funcionamiento?, dtype: object
# ¿La guarda de seguridad y la plataforma de la banda 114 están en funcionamiento?
# 212    Cumple
# 211    Cumple
# 210    Cumple
# 209    Cumple
# 208    Cumple
# 207    Cumple
# 206    Cumple
# 205    Cumple
# 204    Cumple
# Name: ¿El tornillo 115 cuenta con su guarda de seguridad?, dtype: object
# 212
# 211
# 210
# 209
# 208
# 207
# 206
# 205
# 204
# Name: Question4, dtype: object
# 212    hueco en el suelo donde se posiciona el cargad...
# 211    descortazador sin faldones probacando excesiba...
# 210                                 las mismas novedades
# 209    las mismas novedades del turno anterior, falta...
# 208    descortezador sin faldones porvocando excesiva...
# 207                                 las mismas novedades
# 206                  mismas novedades del turno anterior
# 205    descortezador con las mismas novedades de los ...
# 204    se recibe con las mismas novedades de los turn...
# Name: Si requiere mencionar temas, u observaciones, que considere relevantes y que no  están incluidos dentro del cuestionario, por favor diligéncielo en este  espacio \n\n, dtype: object
# Pre-Uso BP2
# Series([], Name: Turno2, dtype: object)
# Series([], Name: Están bien ubicadas y en buenas condiciones las guardas laterales de la vía de rodillos de la zona de entrada de tableros?, dtype: object)
# Series([], Name: Está operativo el paro de emergencia en el tablero de comandos de la zona de inserción?, dtype: object)
# Series([], Name: Están en buen estado y bien ubicados los soportes guía de rechazo de tapas inferiores?, dtype: object)
# Series([], Name: Están en buen estado y bien ubicadas las guardas de seguridad de la vía de rodillos de la zona de inserción?, dtype: object)
# Series([], Name: Están operativos los dos paros de emergencia de la zona de colocación de papel?, dtype: object)
# Series([], Name: Están en buen estado y bien ubicadas las guardas de seguridad inferiores de las bandas en las mesas de colocación de papel?, dtype: object)
# Series([], Name: Están en buen estado las escaleras de acceso a las mesas de colocación de papel?, dtype: object)
# Series([], Name: Se encuentran operativos los sensores de paro por apertura de las 8 puertas en la zona perimetral de la prensa?, dtype: object)
# Series([], Name: Están operativos los dos paros de emergencia en el monitor de prensa y en las puertas de acceso a prensa?, dtype: object)
# Series([], Name: Se encuentran bien ubicadas y en buen estado las guardas de seguridad de la vía de rodillos de la zona de prensa?, dtype: object)
# Series([], Name: Se encuentra operativa la barrera de haz de luz en la zona de clasificación?, dtype: object)
# Series([], Name: Está en buen estado el paro de emergencia en la zona de clasificación?, dtype: object)
# Series([], Name: Se encuentran bien ubicadas y en buen estado las guardas de seguridad de la vía de rodillos de la zona de clasificación?, dtype: object)
# Series([], Name: Se encuentran bien ubicadas y en buen estado las guardas de protección perimetrales de la zona de apilado?, dtype: object)
# Series([], Name: Se encuentra cerrada la puerta de acceso manual a la zona de apilado?, dtype: object)
# Series([], Name: Pregunta, dtype: float64)
# Series([], Name: Si requiere mencionar temas que considere relevantes y que no están incluidos dentro del cuestionario, por favor diligéncielo en este espacio , dtype: object)
# Pre-Uso Formación y Prensa
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas de los motores de la banda 399-05M de entrada de material de los ciclones se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas de los motores de los peines de la formadora se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas de los motores del sistema hidráulico de la pre-prensa se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas de los motores de las sierras laterales de la línea de formación se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas de los motores de la banda 415 se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas de los rodillos de salida de la prensa se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas del sistema hidráulico de enfriamiento de la stacker se encuentran en buen estado y sin averías visibles?, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas de los motores del sistema de calentamiento de la prensa se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas de los motores del sistema hidráulico de la prensa se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿Las guardas de los motores del sistema scrubber se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# 136    Cumple
# 135    Cumple
# 134    Cumple
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: ¿La bomba y el ventilador del sistema scrubber se encuentran en buen estado y sin averías visibles?\n, dtype: object
# 146
# 145
# 144
# 143
# 142
# 141
# 140
# 139
# 138
# 137
# 136
# 135
# 134
# 133
# 132
# 131
# 130
# Name: Observaciones, dtype: object
# 146
# 145
# 144
# 143
# 142
# 141
# 140
# 139
# 138
# 137
# 136
# 135
# 134
# 133
# 132
# 131
# 130
# Name: ¿Las guardas de los motores de la banda 399 de entrada de material de los ciclones se encuentran en buen estado y sin averías visibles?\n, dtype: object
# Pre-Uso Lijadora
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están ubicados y funcionales los topes de piso para las montacargas en la zona de inserción de tableros?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están bien ubicadas y aseguradas las guardas de seguridad existentes de la vía de rodillos?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están bien ubicadas y aseguradas las guardas de seguridad del sistema de transmisión de potencia?, dtype: object
# 133    No Cumple
# 132    No Cumple
# 131    No Cumple
# 130    No Cumple
# Name: Están ubicadas y en buen estado las plataformas de protección existentes tipo parrilla sobre la vía de rodillos?, dtype: object
# Están ubicadas y en buen estado las plataformas de protección existentes tipo parrilla sobre la vía de rodillos?
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están las pasarelas de tránsito e inspección de la lijadora en buen estado?, dtype: object
# 133    No Cumple
# 132       Cumple
# 131    No Cumple
# 130       Cumple
# Name: Están las puertas de acceso a la vía de rodillos cerradas y en buen estado?, dtype: object
# Están las puertas de acceso a la vía de rodillos cerradas y en buen estado?
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: La vía de rodillos del colocador de tapas tiene funcional la barrera de haz de luz?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Está la guarda de seguridad de la mesa elevadora funcional y bien ubicada?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Está cerrada y en óptimas condiciones la guarda de seguridad de las unidades hidráulicas?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están las puertas LO y LCO cerradas y aseguradas?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están los micro switches de seguridad de las puertas LCO operativos?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están cerradas y aseguradas las puertas LCO y LO? (En caso de que se hayan abierto por vibraciones, por favor proceder con su respectivo cierre), dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están habilitados y funcionales los micro switches de LCO?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: El aire acondicionado está operativo?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Las sillas del cuarto de control están en buen estado?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Está cerrada la puerta de la cabina de control durante la operación de la línea?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Está la cabina de control en buenas condiciones de orden y aseo?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están las puertas del CCM cerradas y aseguradas?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están las herramientas completas y en buen estado?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Se encuentran en buen estado los 14 paros de emergencia de la vía de rodillos, mesa elevadora, cuerpo de calibración y cuerpo de satinado?, dtype: object
# 133    Cumple
# 132    Cumple
# 131    Cumple
# 130    Cumple
# Name: Están bien ubicados y funcionales los topes de acceso de montacargas en la zona de colocación de tapas?, dtype: object
# 133
# 132
# 131
# 130
# Name: Pregunta4, dtype: object
# 133     *
# 132    ok
# 131     *
# 130     *
# Name: Observaciones, dtype: object
# Pre-Uso Mantenimiento Mecánico
# 71    No cumple
# 70    No cumple
# 69       Cumple
# 68    No cumple
# 67    No cumple
# Name: ¿Los bancos de trabajo se encuentran libres de osbtaculos?, dtype: object
# ¿Los bancos de trabajo se encuentran libres de osbtaculos?
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿Las cajas y tomas eléctricos se encuentran cerrados y en buenas condiciones?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿El espacio cuenta con un zona agradable o silla ergonómica donde el técnico\n  pueda estar cómodamente en momentos que se amerite?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿El polipasto del taller se encuentra en buenas condiciones?\n, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿Los extintores se encuentran en su lugar?\n, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿La iluminación se encuentra funcional y suficiente?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿los computadores se encuentran operativos y funcionales?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿El piso se encuentra libre obstrucciones?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿El lugar se encuentra aseado?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿Los objetos (gabinetes) en altura se encuentran asegurados?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿El aire acondicionado esta operativo?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿Se encuentra aseada la oficina?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿Las herramientas operativas (manuales, eléctricas, etc.) están en buen estado?, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿El aire acondicionado o ventiladores están operativos?, dtype: object
# 71
# 70
# 69
# 68
# 67
# Name: Question2, dtype: object
# 71
# 70
# 69    Na
# 68
# 67
# Name: Si requiere mencionar temas que considere relevantes y que no  están incluidos dentro del cuestionario, por favor diligéncielo en este  espacio, dtype: object
# 71    Cumple
# 70    Cumple
# 69    Cumple
# 68    Cumple
# 67    Cumple
# Name: ¿los residuos se encuentran en su debido lugar de ubicación?, dtype: object
# 71
# 70
# 69
# 68
# 67
# Name: Pregunta, dtype: object
# Pre-Uso Moduladora y Carpintería
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: Están operativos los 8 paros de Emergencia?, dtype: object
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: Los topes del piso para la montacarga están disponibles?, dtype: object
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: Están ubicadas las 3 guardas de las cuchillas de corte?, dtype: object
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: Verificar que la acumulación de polvo en el paso de la sierra no sea excesiva, dtype: object
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: Verificar presión de aire comprimido (6 bar), dtype: object
# 95       Cumple
# 94       Cumple
# 93    No Cumple
# 92       Cumple
# Name: Están completos los balines de la mesa de corte?, dtype: object
# Están completos los balines de la mesa de corte?
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: Están bien ubicadas las 3 guardas de seguridad frontales de la mesa de corte?, dtype: object
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: Está la cortina de la mesa de corte en posición y con los módulos completos?, dtype: object
# 95       Cumple
# 94       Cumple
# 93    No Cumple
# 92       Cumple
# Name: Están en buen estado las baquelitas del riel de la sierra?, dtype: object
# Están en buen estado las baquelitas del riel de la sierra?
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: El empujador manual está disponible y en condiciones óptimas de uso?, dtype: object
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: El empujador de tacos está disponible y en óptimas condiciones de uso?, dtype: object
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: Verificar que el sistema de colección de polvo esté operativo, dtype: object
# 95    Cumple
# 94    Cumple
# 93    Cumple
# 92    Cumple
# Name: Están disponibles los contenedores para disposición de los retales?, dtype: object
# 95     Walter 19/01/2025 6-2
# 94    Walter 18/01/2025 2-10
# 93      Sebastian 18/01/2025
# 92    walter 17/01/2025 2-10
# Name: Por favor diligencie las novedades que considere relevantes en el desarrollo de la encuesta, dtype: object
# Pre-Uso Planta Térmica
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿La rejilla de ingreso de aire del ventilador terciario se encuentra en buen estado y sin averías visibles?, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿La Guarda de la transmisión del motor del redler de ceniza humeda se encuentra en buen estado y sin averías visibles?, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿Las Guardas de las bombas de aceite termico se encuentran en buen estado y sin averías visibles?, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿Las Guardas de las bombas de agua de la parrilla se encuentran en buen estado y sin averías visibles?, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿Las Guardas de las bombas de agua de la caldera se encuentran en buen estado y sin averías visibles?, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿Las Guardas de los compresores del Booster 1 y 2 se encuentran en buen estado y sin averías visibles?, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿Las rejillas de las baterias de enfriamiento de las parrillas se encuentran en buen estado y sin averías visibles?, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿La rejilla del sistema de inyección de polvo pss2 se encuentra en buen estado y sin averías visibles?, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿La rejilla del sistema de inyección de polvo pss1 se encuentra en buen estado y sin averías visibles?, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿La Guarda de la transmisión del redler de biomasa se encuentra en buen estado y sin averías visibles?\n, dtype: object
# 149    Cumple
# 148    Cumple
# 147    Cumple
# 146    Cumple
# 145    Cumple
# 144    Cumple
# 143    Cumple
# 142    Cumple
# 141    Cumple
# 140    Cumple
# 139    Cumple
# 138    Cumple
# 137    Cumple
# Name: ¿La Guarda de la transmisión del motor del id fan se encuentra en buen estado y sin averías visibles?, dtype: object
# 149
# 148
# 147
# 146
# 145
# 144
# 143
# 142
# 141
# 140
# 139
# 138
# 137
# Name: Observaciones, dtype: object
# Pre-Uso Refinación
# Name: Están bien ubicadas y funcionales las guardas de seguridad de la vía de rodillos de la salida de Schelling?, dtype: object
# 131    No Cumple
# 130    No Cumple
# 129    No Cumple
# 128    No Cumple
# Name: Está bien ubicada y en buen estado la guarda de seguridad de la Sierra Transversal?, dtype: object
# 131    No Cumple
# 130    No Cumple
# 129    No Cumple
# 128    No Cumple
# Name: Está bien ubicada y en buen estado la guarda de seguridad de protección del motor de la Sierra Transversal?, dtype: object
# 131    No Cumple
# 130    No Cumple
# 129    No Cumple
# 128    No Cumple
# Name: Está bien ubicada y en buen estado la guarda de seguridad de la Sierra longitudinal?, dtype: object
# Está bien ubicada y en buen estado la guarda de seguridad de la Sierra longitudinal?
# 131    No Cumple
# 130    No Cumple
# 129    No Cumple
# 128    No Cumple
# Name: Está bien ubicada y en buen estado la guarda de seguridad de protección del motor de la Sierra longitudinal?, dtype: object
# Está bien ubicada y en buen estado la guarda de seguridad de protección del motor de la Sierra longitudinal?
# 131    No Cumple
# 130    No Cumple
# 129    No Cumple
# 128    No Cumple
# Name: Se encuentran las barreras de protección perimetral de la máquina instaladas y en buen estado?, dtype: object
# Se encuentran las barreras de protección perimetral de la máquina instaladas y en buen estado?
# 131    No Cumple
# 130       Cumple
# 129    No Cumple
# 128       Cumple
# Name: Las pasarelas de Schelling tienen antideslizantes en buen estado?, dtype: object
# Las pasarelas de Schelling tienen antideslizantes en buen estado?
# 131    Cumple
# 130    Cumple
# 129    Cumple
# 128    Cumple
# Name: El Chippercito tiene las guardas completas y funcionales del sistema de transmisión de potencia?, dtype: object
# 131     LA MAQUINA NO CUMPLE  CON LOS PASOS PARA REAL...
# 130    Se envía preguntas con opción de mejora y por ...
# 129    LA MAQUINA NO CUMPLE  CON LOS PASOS PARA REALI...
# 128    Se envía preguntas con opción de mejora y por ...
# Name: Observaciones, dtype: object

# %% [markdown]
# # Construction of data to put on presentation

# %% [markdown]
# # Write in presentation
# ## TODO
# * If size of observations is adequate, put no completion entries, questions label and observations in the same slide
# * Table must fit on one slide without exceding the size of the slide

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# %%
def iter_cells(table):
    """
    to change font of text in table
    """
    for row in table.rows:
        for cell in row.cells:
            yield cell

# %%
prs = Presentation()
"""make title slide"""
title_slide_layout = prs.slide_layouts[0]
slide = prs.slides.add_slide(title_slide_layout)
title = slide.shapes.title
subtitle = slide.placeholders[1]

title.text = "Pre-Usos BAR"
subtitle.text = "{}, {}".format(day_before_yesterday_querie.date(),day_to_stop_search_querie.date()) #datetime.now().date()
"""make next slides to inform about pre-usos"""
"""make completion report slide"""
title_no_content_slide_layout=prs.slide_layouts[5]
slide = prs.slides.add_slide(title_no_content_slide_layout)
title = slide.shapes.title
title.text=f"Pre-Usos periodo {subtitle.text}"
title_para = slide.shapes.title.text_frame.paragraphs[0]
title_para.font.size = Pt(20) #set title size
"""make slides to report about No Cumple"""
x, y, cx, cy = Inches(0.1), Inches(1.2), Inches(6), Inches(5)
factorx=0.4
factory=0.25
offsets=[cx*(1-factorx),cy*(1+factory)] #to adjust textbox @right of table
simple_content_slide_layout=prs.slide_layouts[1]
max_font_to_fit_text=16 #value for max font size when fitting text
for pre_uso_name in dict_data_no_cumple.keys(): #take each df with no cumple entries
    slide=prs.slides.add_slide(title_no_content_slide_layout) #slide to add dates and no completion items
    title = slide.shapes.title
    title.text=pre_uso_name

    title_para = slide.shapes.title.text_frame.paragraphs[0]
    title_para.font.size = Pt(20) #set title size
    
    df=dict_data_no_cumple[pre_uso_name].T
    table_rows,table_cols=df.shape
    #print(table_rows,table_cols)
    """insert text box label to identify items with questions"""
    txBox=slide.shapes.add_textbox(x+cx, y, offsets[0], offsets[1])
    tf = txBox.text_frame
    tf.word_wrap = True
    #tf.autofit_text()
    p = tf.add_paragraph()
    text_container = "" #var to store questions of respective pre-uso
    #p.font.size = Pt(12)
    """make table of no completions"""
    shape = slide.shapes.add_table(table_rows-1, table_cols+1, x, y, cx, cy) #table geometry
    table=shape.table
    cell = table.cell(0, 0)
    cell.text="Item"
    df_col_index=list(df.index)[1:] #name of current index which were columns before
    print(df_col_index)
    df_index_col=list(df.columns) #name of current cols which were indexes before
    for idx_col in range(table_cols): #write on header cells of table
        print("indice de columna en tabla: ",idx_col)
        cell = table.cell(0, idx_col+1)
        cell.text="{}".format(df.at[ df_col_index[0],df_index_col[idx_col] ])
     #write on first column to put questions with no completion
    for idx_row in range(table_rows-2):
        print("indice de fila en tabla: ",idx_row)
        cell = table.cell(idx_row+1, 0)
        print(df_col_index[idx_row+1])
        cell.text="{}".format(idx_row+1) #df_col_index[idx_row+1]
        if idx_row<1:
            text_container+= f"->Pregunta {idx_row+1}: "+df_col_index[idx_row+1] #insert text to label_id_questions text box without next line insertion
        else:
            text_container+= f"\n->Pregunta {idx_row+1}: "+df_col_index[idx_row+1] #insert text to label_id_questions text box 
    p.text=text_container #put text on textbox
    tf.fit_text(max_size=max_font_to_fit_text) #adjust text to fit int
    #insert respective data
    for idx_row in range(table_rows-2):
        for idx_col in range(table_cols):
            print("celda value:",idx_row+1,idx_col)
            cell = table.cell(idx_row+1, idx_col+1)
            cell.text="{}".format(df.at[ df_col_index[idx_row+1],df_index_col[idx_col] ]) #insert df value
    """to change table text font"""
    for cell in iter_cells(table):
        for paragraph in cell.text_frame.paragraphs:
            for run in paragraph.runs:
                run.font.size = Pt(12)
    """to add observations"""
    string_to_add_observations=""
    flag_make_observations_slide=False
    for idx_col in range(table_cols):
    #put date of observation and observation content
        observation=df.at[ list(df.index)[0],df_index_col[idx_col] ]
        min_lenght_observation=40 #min lenght of observation to be inserted on slides report
        if len(observation)<min_lenght_observation: #if observation lenght is minor to 28 chars, continue
            continue
        else:
            flag_make_observations_slide=True
            if idx_col<1:
                string_to_add_observations+=f"Observación {df.at[ df_col_index[0],df_index_col[idx_col] ]}: {observation}" #insert 1st observation without next line insertion
            else:
                string_to_add_observations+=f"\nObservación {df.at[ df_col_index[0],df_index_col[idx_col] ]}: {observation}" #insert 1st observation without next line insertion            
    if flag_make_observations_slide:
        slide=prs.slides.add_slide(simple_content_slide_layout) #slide to add observations
        title = slide.shapes.title
        title.text="{}-{}".format(pre_uso_name,"Observaciones")
    
        title_para = slide.shapes.title.text_frame.paragraphs[0]
        title_para.font.size = Pt(28) #set title size
        """insert content on text box place holder"""
        content_tf=slide.placeholders[1]
        format_text_props=content_tf.text_frame
        format_text_props.word_wrap=True
        content_tf.text=string_to_add_observations
        format_text_props.fit_text(max_size=max_font_to_fit_text) #adjust text to fit int

presentation_date=day_to_stop_search_querie.date()#.strftime('%d-%m-%Y')
print(presentation_date)
year_folder=rf"\year_{presentation_date.year}"
month_folder=rf"\month_{day_to_stop_search_querie.month}"
directory=r"pptx_reports"
directory_to_save = Path.joinpath(path,str(directory)+year_folder+month_folder) # get directory to save plot
directory_to_save.mkdir(exist_ok=True)
prs.save(str(directory_to_save)+rf"\Preusos Producción y MMTTO_{presentation_date}.pptx")
prs.save(Path.joinpath(path,str(directory)+r'\test\test.pptx'))
# Out:
# ['Hora de inicio', '¿Las cajas de control, empaques, cableado y tomas eléctricos se encuentran cerrados y en buen estado?', '¿Están ubicadas y funcionales las 6 guardas de seguridad del tambor descortezador?', '¿La unidad hidráulica y accesorios presentan algún tipo de fuga?', '¿Las escaleras, pasamanos y paros de cuerdas están funcionales y libre de obstrucciones?', '¿Las barreras perimetrales de la mesa transversal están ubicadas y funcionales?', '¿Están ubicadas y funcionales las guardas de seguridad de las bandas de descarga de corteza, transportadora de tronco y\xa0alimentación al chipper?', '¿Las escaleras, pasamanos y senderos peatonales están libre de obstrucciones y en buen estado?', '¿Las barreras perimetrales de las poleas de las poleas del Chipper están ubicadas y funcionales?', '¿Las guardas de seguridad de los rodillos dentados están ubicadas y funcionales (8 unidades)?', '¿La unidad hidráulica del chipper cuenta con su guarda de seguridad?', '¿Las cajas eléctricas, el pin de bloqueo y los tornillos de ajustes del Chipper están ajustados?', '¿Se encuentran cerradas las tapas del shute?', '¿La guarda de seguridad de los tornillos gemelos están ubicadas y funcionales?', '¿La guarda de seguridad y la plataforma de la banda 114 están en funcionamiento?']
# indice de columna en tabla:  0
# indice de columna en tabla:  1
# indice de columna en tabla:  2
# indice de columna en tabla:  3
# indice de columna en tabla:  4
# indice de columna en tabla:  5
# indice de columna en tabla:  6
# indice de columna en tabla:  7
# indice de columna en tabla:  8
# indice de fila en tabla:  0
# ¿Las cajas de control, empaques, cableado y tomas eléctricos se encuentran cerrados y en buen estado?
# indice de fila en tabla:  1
# ¿Están ubicadas y funcionales las 6 guardas de seguridad del tambor descortezador?
# indice de fila en tabla:  2
# ¿La unidad hidráulica y accesorios presentan algún tipo de fuga?
# indice de fila en tabla:  3
# ¿Las escaleras, pasamanos y paros de cuerdas están funcionales y libre de obstrucciones?
# indice de fila en tabla:  4
# ¿Las barreras perimetrales de la mesa transversal están ubicadas y funcionales?
# indice de fila en tabla:  5
# ¿Están ubicadas y funcionales las guardas de seguridad de las bandas de descarga de corteza, transportadora de tronco y alimentación al chipper?
# celda value: 13 1
# celda value: 13 2
# celda value: 13 3
# celda value: 13 4
# celda value: 13 5
# celda value: 13 6
# celda value: 13 7
# celda value: 13 8
# celda value: 14 0
# celda value: 14 1
# celda value: 14 2
# celda value: 14 3
# celda value: 14 4
# celda value: 14 5
# celda value: 14 6
# celda value: 14 7
# celda value: 14 8
# ['Hora de inicio', 'Están ubicadas y en buen estado las plataformas de protección existentes tipo parrilla sobre la vía de rodillos?', 'Están las puertas de acceso a la vía de rodillos cerradas y en buen estado?']
# indice de columna en tabla:  0
# indice de columna en tabla:  1
# indice de columna en tabla:  2
# indice de columna en tabla:  3
# indice de fila en tabla:  0
# Están ubicadas y en buen estado las plataformas de protección existentes tipo parrilla sobre la vía de rodillos?
# indice de fila en tabla:  1
# Están las puertas de acceso a la vía de rodillos cerradas y en buen estado?
# celda value: 1 0
# celda value: 1 1
# celda value: 1 2
# celda value: 1 3
# celda value: 2 0
# celda value: 2 1
# celda value: 2 2
# celda value: 2 3
# ['Start time', '¿Los bancos de trabajo se encuentran libres de osbtaculos?']
# indice de columna en tabla:  0
# indice de columna en tabla:  1
# indice de columna en tabla:  2
# indice de columna en tabla:  3
# indice de fila en tabla:  0
# ¿Los bancos de trabajo se encuentran libres de osbtaculos?
# celda value: 1 0
# celda value: 1 1
# celda value: 1 2
# celda value: 1 3
# ['Hora de inicio', 'Están completos los balines de la mesa de corte?', 'Están en buen estado las baquelitas del riel de la sierra?']
# indice de columna en tabla:  0
# indice de fila en tabla:  0
# Están completos los balines de la mesa de corte?
# indice de fila en tabla:  1
# Están en buen estado las baquelitas del riel de la sierra?
# celda value: 1 0
# celda value: 2 0
# ['Hora de inicio', 'Las sillas del cuarto de control están en buen estado?', 'Está bien ubicada y en buen estado la guarda de seguridad de la Sierra longitudinal?', 'Está bien ubicada y en buen estado la guarda de seguridad de protección del motor de la Sierra longitudinal?', 'Se encuentran las barreras de protección perimetral de la máquina instaladas y en buen estado?', 'Las pasarelas de Schelling tienen antideslizantes en buen estado?']
# indice de columna en tabla:  0
# indice de columna en tabla:  1
# indice de columna en tabla:  2
# indice de columna en tabla:  3
# indice de fila en tabla:  0
# Las sillas del cuarto de control están en buen estado?
# indice de fila en tabla:  1
# Está bien ubicada y en buen estado la guarda de seguridad de la Sierra longitudinal?
# indice de fila en tabla:  2
# Está bien ubicada y en buen estado la guarda de seguridad de protección del motor de la Sierra longitudinal?
# indice de fila en tabla:  3
# Se encuentran las barreras de protección perimetral de la máquina instaladas y en buen estado?
# indice de fila en tabla:  4
# Las pasarelas de Schelling tienen antideslizantes en buen estado?
# celda value: 1 0
# celda value: 1 1
# celda value: 1 2
# celda value: 1 3
# celda value: 2 0
# celda value: 2 1
# celda value: 2 2
# celda value: 2 3
# celda value: 3 0
# celda value: 3 1
# celda value: 3 2
# celda value: 3 3
# celda value: 4 0
# celda value: 4 1
# celda value: 4 2
# celda value: 4 3
# celda value: 5 0
# celda value: 5 1
# celda value: 5 2
# celda value: 5 3
# 2025-01-19
